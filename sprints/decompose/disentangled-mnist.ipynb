# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# http://www.cs.toronto.edu/~nitish/unsupervised_video/
mnist = np.load('/home/telfaralex/Downloads/mnist_test_seq.npy')

# %%
mnist.shape
# Out:
# (20, 10000, 64, 64)

# %%
for i in range(20):
    plt.figure()
    for j in range(4):
        plt.subplot(1, 4, j+1)
        plt.imshow(mnist[i, j, ...], cmap='gray')
